# %% [markdown]
# ## Statistical Inference and EDA of BTC/ETH prices and GoogleNews search frequency of the word "cryptocurrency"
#
# Due to volatility of crytocurrency market, one might wonder what is the best way to predict the currencies prices. As I came up with the project idea, the preliminary questions I had in mind were:
#
# 1. Is there any obvious correlation/lead-lag relationship between different crytocurrency market prices?
# 2. If the correlation between a pair of currencies A and B existed, can we use currency A price history to predict future price of currency B? Will it be more useful than using just historical prices of currency B alone?
# 3. Does the rise/fall in search frequency of the word "crytocurrency" on GoogleNews imply trading signal?
#
# The following code queries, visualizes, and tests data in order to explore the preliminary questions. The stretch goal is to gain insights beyond preliminary questions that will lead to better data analysis in the future

# %%
# Getting price data of BTC and ETH using Cryptocompare API

import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime

# Indicate how many rows of data here
lim = '2000' 
story_coin = ['BTC', 'ETH']
story_data = pd.DataFrame()
for i in story_coin:
    URL = 'https://min-api.cryptocompare.com/data/histohour?fsym='+i+'&tsym=USD&limit='+lim
    data = requests.get(URL)
    json_data = data.json()
    table = json_normalize(json_data, 'Data').set_index('time')
    table.index = pd.to_datetime(table.index ,unit='s')
    story_data = pd.concat([story_data, table.high], axis=1)
story_data.columns = story_coin

# %%
# Getting data from Google Trends using Pytrends API

from pytrends.request import TrendReq
# Login to Google. Only need to run this once
pytrend = TrendReq()
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
# keyword = 'cryptocurrency', cathegory = 16 (news), timeframe- limit range to 8 months to get daily data
pytrend.build_payload(kw_list=['cryptocurrency'], cat=16, timeframe='2019-03-05 2019-05-28')  

story_ggtrends = pytrend.interest_over_time()
# Upsampling daily data to hourly data
story_ggtrends = story_ggtrends.resample('1h').pad().drop(['isPartial'], axis='columns')
story_ggtrends.columns = ['SearchFrequency']
story_ggtrends
# Out:
#                      SearchFrequency
# date
# 2019-03-05 00:00:00               31
# 2019-03-05 01:00:00               31
# 2019-03-05 02:00:00               31
# 2019-03-05 03:00:00               31
# 2019-03-05 04:00:00               31
# 2019-03-05 05:00:00               31
# 2019-03-05 06:00:00               31
# 2019-03-05 07:00:00               31
# 2019-03-05 08:00:00               31
# 2019-03-05 09:00:00               31
# 2019-03-05 10:00:00               31
# 2019-03-05 11:00:00               31
# 2019-03-05 12:00:00               31
# 2019-03-05 13:00:00               31
# 2019-03-05 14:00:00               31
# 2019-03-05 15:00:00               31
# 2019-03-05 16:00:00               31
# 2019-03-05 17:00:00               31
# 2019-03-05 18:00:00               31
# 2019-03-05 19:00:00               31
# 2019-03-05 20:00:00               31
# 2019-03-05 21:00:00               31
# 2019-03-05 22:00:00               31
# 2019-03-05 23:00:00               31
# 2019-03-06 00:00:00               34
# 2019-03-06 01:00:00               34
# 2019-03-06 02:00:00               34
# 2019-03-06 03:00:00               34
# 2019-03-06 04:00:00               34
# 2019-03-06 05:00:00               34
# ...                              ...
# 2019-05-23 19:00:00               27
# 2019-05-23 20:00:00               27
# 2019-05-23 21:00:00               27
# 2019-05-23 22:00:00               27
# 2019-05-23 23:00:00               27
# 2019-05-24 00:00:00               44
# 2019-05-24 01:00:00               44
# 2019-05-24 02:00:00               44
# 2019-05-24 03:00:00               44
# 2019-05-24 04:00:00               44
# 2019-05-24 05:00:00               44
# 2019-05-24 06:00:00               44
# 2019-05-24 07:00:00               44
# 2019-05-24 08:00:00               44
# 2019-05-24 09:00:00               44
# 2019-05-24 10:00:00               44
# 2019-05-24 11:00:00               44
# 2019-05-24 12:00:00               44
# 2019-05-24 13:00:00               44
# 2019-05-24 14:00:00               44
# 2019-05-24 15:00:00               44
# 2019-05-24 16:00:00               44
# 2019-05-24 17:00:00               44
# 2019-05-24 18:00:00               44
# 2019-05-24 19:00:00               44
# 2019-05-24 20:00:00               44
# 2019-05-24 21:00:00               44
# 2019-05-24 22:00:00               44
# 2019-05-24 23:00:00               44
# 2019-05-25 00:00:00               33
#
# [1945 rows x 1 columns]

# %%
# Joining two data frames

story_combined = pd.concat([story_data, story_ggtrends], axis=1).dropna()
print(story_combined)
story_combined_scaled = story_combined.copy(deep=True)
# Out:
#                          BTC     ETH  SearchFrequency
# time
# 2019-03-05 19:00:00  3878.59  138.13             31.0
# 2019-03-05 20:00:00  3876.67  138.01             31.0
# 2019-03-05 21:00:00  3866.09  137.09             31.0
# 2019-03-05 22:00:00  3865.36  137.15             31.0
# 2019-03-05 23:00:00  3874.60  137.94             31.0
# 2019-03-06 00:00:00  3884.87  140.54             34.0
# 2019-03-06 01:00:00  3857.16  137.39             34.0
# 2019-03-06 02:00:00  3858.38  137.40             34.0
# 2019-03-06 03:00:00  3858.42  137.41             34.0
# 2019-03-06 04:00:00  3852.88  136.67             34.0
# 2019-03-06 05:00:00  3860.01  137.16             34.0
# 2019-03-06 06:00:00  3870.58  138.36             34.0
# 2019-03-06 07:00:00  3874.36  138.78             34.0
# 2019-03-06 08:00:00  3866.67  138.28             34.0
# 2019-03-06 09:00:00  3871.40  138.93             34.0
# 2019-03-06 10:00:00  3916.29  141.71             34.0
# 2019-03-06 11:00:00  3883.44  140.00             34.0
# 2019-03-06 12:00:00  3881.40  139.84             34.0
# 2019-03-06 13:00:00  3876.12  139.08             34.0
# 2019-03-06 14:00:00  3865.08  138.11             34.0
# 2019-03-06 15:00:00  3874.12  139.06             34.0
# 2019-03-06 16:00:00  3879.68  138.98             34.0
# 2019-03-06 17:00:00  3879.34  138.92             34.0
# 2019-03-06 18:00:00  3873.15  138.20             34.0
# 2019-03-06 19:00:00  3874.66  138.60             34.0
# 2019-03-06 20:00:00  3870.10  138.06             34.0
# 2019-03-06 21:00:00  3872.56  138.31             34.0
# 2019-03-06 22:00:00  3877.35  138.78             34.0
# 2019-03-06 23:00:00  3878.25  139.04             34.0
# 2019-03-07 00:00:00  3891.11  139.61             28.0
# ...                      ...     ...              ...
# 2019-05-23 19:00:00  7792.96  242.02             27.0
# 2019-05-23 20:00:00  7872.48  244.77             27.0
# 2019-05-23 21:00:00  7942.95  247.02             27.0
# 2019-05-23 22:00:00  7971.26  248.32             27.0
# 2019-05-23 23:00:00  7934.82  247.43             27.0
# 2019-05-24 00:00:00  7884.30  246.24             44.0
# 2019-05-24 01:00:00  7929.16  247.13             44.0
# 2019-05-24 02:00:00  7878.60  245.26             44.0
# 2019-05-24 03:00:00  7883.68  245.71             44.0
# 2019-05-24 04:00:00  7893.14  246.00             44.0
# 2019-05-24 05:00:00  7847.77  244.24             44.0
# 2019-05-24 06:00:00  7879.26  247.01             44.0
# 2019-05-24 07:00:00  7904.52  249.52             44.0
# 2019-05-24 08:00:00  8021.85  252.49             44.0
# 2019-05-24 09:00:00  7991.52  251.54             44.0
# 2019-05-24 10:00:00  8025.03  252.76             44.0
# 2019-05-24 11:00:00  8064.31  253.95             44.0
# 2019-05-24 12:00:00  8040.94  252.88             44.0
# 2019-05-24 13:00:00  8041.01  253.03             44.0
# 2019-05-24 14:00:00  8058.65  253.81             44.0
# 2019-05-24 15:00:00  8134.40  255.11             44.0
# 2019-05-24 16:00:00  8165.45  255.80             44.0
# 2019-05-24 17:00:00  8106.30  254.22             44.0
# 2019-05-24 18:00:00  8092.26  252.92             44.0
# 2019-05-24 19:00:00  8072.87  252.75             44.0
# 2019-05-24 20:00:00  8103.94  253.85             44.0
# 2019-05-24 21:00:00  8118.61  254.14             44.0
# 2019-05-24 22:00:00  8090.45  252.25             44.0
# 2019-05-24 23:00:00  8036.80  250.44             44.0
# 2019-05-25 00:00:00  8015.88  250.12             33.0
#
# [1926 rows x 3 columns]

# %%
# Feature Scaling. This will capture trend information and makes visualization more meaningful

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
story_combined_scaled['BTC'] = sc_x.fit_transform(story_combined_scaled['BTC'].values.reshape(-1,1))
story_combined_scaled['ETH'] = sc_x.fit_transform(story_combined_scaled['ETH'].values.reshape(-1,1))
story_combined_scaled['SearchFrequency'] = sc_x.fit_transform(story_combined_scaled['SearchFrequency'].values.reshape(-1,1))

# %%
# Plot 1- scaled overlay plot of ETC/BTC prices and GoogleNews search frequency data

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.plot(story_combined_scaled.index, story_combined_scaled['ETH'], color='blue')
plt.plot(story_combined_scaled.index, story_combined_scaled['BTC'], color='green')
plt.plot(story_combined_scaled.index, story_combined_scaled['SearchFrequency'], color='red')
#plt.xlim(('2017-07-26', '2017-10-10'))
plt.legend(loc='upper left')
plt.xlabel('Time')
plt.ylabel('Prices & Search Frequency (scaled)')
plt.title('Plot 1')
plt.show()

# %% [markdown]
# From **Plot 1**, I've obsereved the following:
# 1. Sharp rises in search frequency are coupled with price drops
# 2. BTC and ETH prices tend to converge during drops, and not spikes (notice that the series were scaled)

# %%
# Plot 2- scaled overlay plot of ETC/BTC prices and GoogleNews search frequency data in 20 days timespand (during drop)

plt.plot(story_combined_scaled.index, story_combined_scaled['ETH'], color='blue')
plt.plot(story_combined_scaled.index, story_combined_scaled['BTC'], color='green')
plt.plot(story_combined_scaled.index, story_combined_scaled['SearchFrequency'], color='red')
plt.xlim(('2019-03-05', '2019-05-28'))
plt.legend(loc='lower left')
plt.xlabel('Time')
plt.ylabel('Prices & Search Frequency (scaled)')
plt.title('Plot 2')
plt.show()

# %% [markdown]
# According to **Plot 2**, it looks like sharp rise in search frequency leads ETH/BTC price drop. However, this conclusion is based on just 2 events

# %%
# Plot 3- BTC/ETH moving averages (scaled)

import numpy as np
a = 50
b = a-1
def moving_average(a, n):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

ma_combined = pd.DataFrame()
ma_combined['ETH'] = moving_average(story_combined_scaled['ETH'].values, a)
ma_combined['BTC'] = moving_average(story_combined_scaled['BTC'].values, a)

plt.plot(ma_combined.index, ma_combined['BTC'], color='green', label = 'Avg_BTC')
plt.plot(ma_combined.index, ma_combined['ETH'], color='blue', label = 'Avg_ETH')
plt.legend(loc='lower left')
plt.ylabel('Prices(scaled)')
plt.xlabel('Time')
plt.title('Plot 3')
plt.show()

# %% [markdown]
# Based on **Plot 3** , there seem to be correlation between ETH and BTC prices and that ETH leads BTC. However, Granger Causality Test will be performed to confirm the relationship. There's no obvious trend (varying mean over time) or seasonality (varying variance over time) observed at this range. However, Dickey-Fuller test will be perfrom to confirm stationality of the series.

# %%
# Plot 4- Box plot by hour of the day

from datetime import datetime, timezone
from collections import OrderedDict
from collections import defaultdict

for coin in story_coin:
    group = OrderedDict.fromkeys(story_combined[coin].index.hour)
    group = defaultdict(list)
    for i in story_combined[coin].index:
        group[i.hour].append(story_combined[coin][i])
    lenght = []
    for key in group:
        lenght.append(len(group[key]))
    min_len = min(lenght)
    hour = pd.DataFrame()
    for key, value in group.items():
        hour[key] = value[:min_len]
    hour.boxplot()
    plt.ylabel('Price')
    plt.xlabel('Hours of the Days')
    plt.title('Plot 4-{}'.format(coin), loc='center')
    plt.show()

# %%
# Plot 5- Box plot by day of the month

for coin in story_coin:    
    group = OrderedDict.fromkeys(story_combined[coin].index.day)
    group = defaultdict(list)
    for i in story_combined[coin].index:
        group[i.day].append(story_combined[coin][i])
    lenght = []
    for key in group:
        lenght.append(len(group[key]))
    min_len = min(lenght)
    day = pd.DataFrame()
    for key, value in group.items():
        day[key] = value[:min_len]
    

    day.boxplot()
    plt.ylabel('Price')
    plt.xlabel('Days of the Months')
    plt.title('Plot 5-{}'.format(coin), loc='center')
    plt.show()

# %% [markdown]
# **plot 4** shows relatively constant mean, but varying variance throughout hours of the day. However, there's no common patterns observed between BTC and ETH prices stats, which leads me to belive seasonality doesn't exist in these series.

# %%
# Plot 6- BTC/ETH histogram

n_data = len(story_combined['ETH'])
n_bins = int(np.sqrt(n_data))
plt.subplot(1, 2, 1)
story_combined['ETH'].hist(bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Plot 6- ETH', loc='center')
plt.subplot(1, 2, 2)
story_combined['BTC'].hist(bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Plot 6- BTC', loc='center')
plt.show()

# %% [markdown]
# **Plot 4** shows that ETH has a sharp frequency peak at ~300, while BTC doesn't have such sharp peak. Depending on personal judgement, if the ETH peak was more extream, it might have been helpful to bias the ETH model to 300. Moreover, BTC histrogram is slightly skewed left, which may have implied BTC market is less "stable". We will further explore histograms of both series after differncing to better quantify "stability".

# %%
# Plot 7- BTC/ETH lag1 scatter plot

from pandas.plotting import lag_plot
plt.subplot(1, 2, 1)
lag_plot(story_combined['ETH'])
plt.title('Plot 7- ETH', loc='center')
plt.subplot(1, 2, 2)
lag_plot(story_combined['BTC'])
plt.title('Plot 7- BTC', loc='center')
plt.show()

# %% [markdown]
# **Plot 5** suggests positive correlation between observations and their consecutive observations (y_t and y_t-1) in both BTC and ETH. To further explore the series, we're going to look at Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF) plots which measure the linear predictability of the series at time t, say x_t, using the value x_s, where s and t denote two valuation points in time. Before we explore ACF and PACF plots, we need to stationarize the series.

# %%
# Result 1- Perform Dickey Fuller Test to determine stationality of BTC and ETC time series

from statsmodels.tsa.stattools import adfuller
x = story_combined['ETH'].values
DF_ETH = adfuller(x)
print('\n')
print('\033[1m' + 'Result 1' + '\033[0m')
print('ADF Statistic (ETH): %f' % DF_ETH[0])
print('p-value: %f' % DF_ETH[1])
print('Critical Values:')
for key, value in DF_ETH[4].items():
    print('\t%s: %.3f' % (key, value))

y = story_combined['BTC'].values
DF_BTC = adfuller(y)
print('\n')
print('ADF Statistic (BTC): %f' % DF_BTC[0])
print('p-value: %f' % DF_BTC[1])
print('Critical Values:')
for key, value in DF_BTC[4].items():
    print('\t%s: %.3f' % (key, value))
print('\n')
# Out:
# Result 1
# ADF Statistic (ETH): -0.203409
# p-value: 0.938114
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#
#
# ADF Statistic (BTC): 0.248897
# p-value: 0.974875
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %% [markdown]
# From **Result 1** above, Dickey-Fuller test shows that both ETH and BTC are NOT stationary series. To stationarize the series, we're going to perform differencing. There are combinations of lag difference and difference order we could pick from. First, we're going to take the difference using lag 1 order 1 on both series.

# %%
# Perfrom differencing to stationalize the series

# create a differenced series, with default value of lag 1
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return diff

# difference the dataset
diff_BTC = difference(story_combined['BTC'])
diff_ETH = difference(story_combined['ETH'])

diff_2 = difference(story_combined['ETH'], 2)
diff_24 = difference(story_combined['ETH'], 24)

# invert differenced forecast #
def inverse_difference(last_ob, value):
   return value + last_ob
# invert the difference #
# inverted = [inverse_difference(data[i], diff[i]) for i in range(len(diff))]
# print(inverted)

# %%
diff_BTC = np.diff(story_combined['BTC'], 2)
diff_ETH = np.diff(story_combined['ETH'], 2)

# %%
# Result 2- Perfrom Dickey-Fuller Test on the differenced series

DF_diff_BTC = adfuller(diff_BTC)
print('\n')
print('\033[1m' + 'Result 2' + '\033[0m')
print('ADF Statistic (BTC): %f' % DF_diff_BTC[0])
print('p-value: %f' % DF_diff_BTC[1])
print('Critical Values:')
for key, value in DF_diff_BTC[4].items():
    print('\t%s: %.3f' % (key, value))
    
    
DF_diff_ETH = adfuller(diff_ETH)
print('\n')
print('ADF Statistic (ETH): %f' % DF_diff_ETH[0])
print('p-value: %f' % DF_diff_ETH[1])
print('Critical Values:')
for key, value in DF_diff_ETH[4].items():
    print('\t%s: %.3f' % (key, value))
print('\n')
# Out:
# Result 2
# ADF Statistic (BTC): -14.277148
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
#
#
# ADF Statistic (ETH): -17.830879
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568

# %% [markdown]
# Based on **Result 2**, differencing using lag 1 order 1 improved the stationarity. Both BTC and ETH are now stationary series.

# %%
# Plot8- Plotting Histogram of differenced series

n_data = len(diff_ETH)
n_bins = int(np.sqrt(n_data))
plt.subplot(1, 2, 1)
plt.hist(diff_BTC, bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Differenced Price')
plt.title('Plot 8- BTC', loc='center')
plt.subplot(1, 2, 2)
plt.hist(diff_ETH, bins=n_bins)
plt.ylabel('Frequency')
plt.xlabel('Differenced Price')
plt.title('Plot 8- ETH', loc='center')
plt.show()

# %% [markdown]
# Histogram of the difference, **Plot 6**, shows that the distribution is skewed left. This distribution implies that spiking is more "rapid" than falling. Threshold based on standard deviation of this plot could be used to define "stability" of the series.

# %%
# Result 3- Perfrom Granger Causality Test with the null hypothesis of ETH doesn't Granger cause BTC

import statsmodels.tsa.stattools as sm
diff_BTC_ETH = pd.DataFrame()
diff_BTC_ETH['BTC'] = diff_BTC
diff_BTC_ETH['ETH'] = diff_ETH
print('Result 3')
cor = sm.grangercausalitytests(diff_BTC_ETH, 50)
# Out:
# Result 3
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=23.3422 , p=0.0000  , df_denom=1920, df_num=1
# ssr based chi2 test:   chi2=23.3787 , p=0.0000  , df=1
# likelihood ratio test: chi2=23.2377 , p=0.0000  , df=1
# parameter F test:         F=23.3422 , p=0.0000  , df_denom=1920, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.8951 , p=0.0000  , df_denom=1917, df_num=2
# ssr based chi2 test:   chi2=21.8470 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.7238 , p=0.0000  , df=2
# parameter F test:         F=10.8951 , p=0.0000  , df_denom=1917, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=11.0371 , p=0.0000  , df_denom=1914, df_num=3
# ssr based chi2 test:   chi2=33.2323 , p=0.0000  , df=3
# likelihood ratio test: chi2=32.9481 , p=0.0000  , df=3
# parameter F test:         F=11.0371 , p=0.0000  , df_denom=1914, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=7.5550  , p=0.0000  , df_denom=1911, df_num=4
# ssr based chi2 test:   chi2=30.3624 , p=0.0000  , df=4
# likelihood ratio test: chi2=30.1248 , p=0.0000  , df=4
# parameter F test:         F=7.5550  , p=0.0000  , df_denom=1911, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.0021  , p=0.0000  , df_denom=1908, df_num=5
# ssr based chi2 test:   chi2=30.1834 , p=0.0000  , df=5
# likelihood ratio test: chi2=29.9485 , p=0.0000  , df=5
# parameter F test:         F=6.0021  , p=0.0000  , df_denom=1908, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.7874  , p=0.0000  , df_denom=1905, df_num=6
# ssr based chi2 test:   chi2=34.9616 , p=0.0000  , df=6
# likelihood ratio test: chi2=34.6468 , p=0.0000  , df=6
# parameter F test:         F=5.7874  , p=0.0000  , df_denom=1905, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.6480  , p=0.0000  , df_denom=1902, df_num=7
# ssr based chi2 test:   chi2=32.7925 , p=0.0000  , df=7
# likelihood ratio test: chi2=32.5152 , p=0.0000  , df=7
# parameter F test:         F=4.6480  , p=0.0000  , df_denom=1902, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.9648  , p=0.0001  , df_denom=1899, df_num=8
# ssr based chi2 test:   chi2=32.0025 , p=0.0001  , df=8
# likelihood ratio test: chi2=31.7382 , p=0.0001  , df=8
# parameter F test:         F=3.9648  , p=0.0001  , df_denom=1899, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.4879  , p=0.0003  , df_denom=1896, df_num=9
# ssr based chi2 test:   chi2=31.7054 , p=0.0002  , df=9
# likelihood ratio test: chi2=31.4458 , p=0.0002  , df=9
# parameter F test:         F=3.4879  , p=0.0003  , df_denom=1896, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.6789  , p=0.0001  , df_denom=1893, df_num=10
# ssr based chi2 test:   chi2=37.1971 , p=0.0001  , df=10
# likelihood ratio test: chi2=36.8402 , p=0.0001  , df=10
# parameter F test:         F=3.6789  , p=0.0001  , df_denom=1893, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=3.3450  , p=0.0001  , df_denom=1890, df_num=11
# ssr based chi2 test:   chi2=37.2429 , p=0.0001  , df=11
# likelihood ratio test: chi2=36.8850 , p=0.0001  , df=11
# parameter F test:         F=3.3450  , p=0.0001  , df_denom=1890, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=3.1394  , p=0.0002  , df_denom=1887, df_num=12
# ssr based chi2 test:   chi2=38.1723 , p=0.0001  , df=12
# likelihood ratio test: chi2=37.7962 , p=0.0002  , df=12
# parameter F test:         F=3.1394  , p=0.0002  , df_denom=1887, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.8469  , p=0.0005  , df_denom=1884, df_num=13
# ssr based chi2 test:   chi2=37.5397 , p=0.0003  , df=13
# likelihood ratio test: chi2=37.1758 , p=0.0004  , df=13
# parameter F test:         F=2.8469  , p=0.0005  , df_denom=1884, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.5715  , p=0.0011  , df_denom=1881, df_num=14
# ssr based chi2 test:   chi2=36.5554 , p=0.0009  , df=14
# likelihood ratio test: chi2=36.2100 , p=0.0010  , df=14
# parameter F test:         F=2.5715  , p=0.0011  , df_denom=1881, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.2702  , p=0.0036  , df_denom=1878, df_num=15
# ssr based chi2 test:   chi2=34.6154 , p=0.0028  , df=15
# likelihood ratio test: chi2=34.3053 , p=0.0031  , df=15
# parameter F test:         F=2.2702  , p=0.0036  , df_denom=1878, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.0173  , p=0.0096  , df_denom=1875, df_num=16
# ssr based chi2 test:   chi2=32.8446 , p=0.0077  , df=16
# likelihood ratio test: chi2=32.5651 , p=0.0084  , df=16
# parameter F test:         F=2.0173  , p=0.0096  , df_denom=1875, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=1.9283  , p=0.0126  , df_denom=1872, df_num=17
# ssr based chi2 test:   chi2=33.3942 , p=0.0100  , df=17
# likelihood ratio test: chi2=33.1051 , p=0.0109  , df=17
# parameter F test:         F=1.9283  , p=0.0126  , df_denom=1872, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.0095  , p=0.0071  , df_denom=1869, df_num=18
# ssr based chi2 test:   chi2=36.8878 , p=0.0054  , df=18
# likelihood ratio test: chi2=36.5354 , p=0.0060  , df=18
# parameter F test:         F=2.0095  , p=0.0071  , df_denom=1869, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=1.9268  , p=0.0094  , df_denom=1866, df_num=19
# ssr based chi2 test:   chi2=37.3734 , p=0.0071  , df=19
# likelihood ratio test: chi2=37.0115 , p=0.0079  , df=19
# parameter F test:         F=1.9268  , p=0.0094  , df_denom=1866, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=1.9896  , p=0.0057  , df_denom=1863, df_num=20
# ssr based chi2 test:   chi2=40.6684 , p=0.0041  , df=20
# likelihood ratio test: chi2=40.2401 , p=0.0047  , df=20
# parameter F test:         F=1.9896  , p=0.0057  , df_denom=1863, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=2.0832  , p=0.0027  , df_denom=1860, df_num=21
# ssr based chi2 test:   chi2=44.7578 , p=0.0019  , df=21
# likelihood ratio test: chi2=44.2395 , p=0.0022  , df=21
# parameter F test:         F=2.0832  , p=0.0027  , df_denom=1860, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=2.1023  , p=0.0020  , df_denom=1857, df_num=22
# ssr based chi2 test:   chi2=47.3710 , p=0.0013  , df=22
# likelihood ratio test: chi2=46.7907 , p=0.0016  , df=22
# parameter F test:         F=2.1023  , p=0.0020  , df_denom=1857, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=2.0063  , p=0.0031  , df_denom=1854, df_num=23
# ssr based chi2 test:   chi2=47.3144 , p=0.0020  , df=23
# likelihood ratio test: chi2=46.7352 , p=0.0024  , df=23
# parameter F test:         F=2.0063  , p=0.0031  , df_denom=1854, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=2.0349  , p=0.0022  , df_denom=1851, df_num=24
# ssr based chi2 test:   chi2=50.1301 , p=0.0014  , df=24
# likelihood ratio test: chi2=49.4802 , p=0.0016  , df=24
# parameter F test:         F=2.0349  , p=0.0022  , df_denom=1851, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=2.1444  , p=0.0008  , df_denom=1848, df_num=25
# ssr based chi2 test:   chi2=55.0904 , p=0.0005  , df=25
# likelihood ratio test: chi2=54.3064 , p=0.0006  , df=25
# parameter F test:         F=2.1444  , p=0.0008  , df_denom=1848, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=2.2948  , p=0.0002  , df_denom=1845, df_num=26
# ssr based chi2 test:   chi2=61.3786 , p=0.0001  , df=26
# likelihood ratio test: chi2=60.4070 , p=0.0001  , df=26
# parameter F test:         F=2.2948  , p=0.0002  , df_denom=1845, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=2.4038  , p=0.0001  , df_denom=1842, df_num=27
# ssr based chi2 test:   chi2=66.8400 , p=0.0000  , df=27
# likelihood ratio test: chi2=65.6894 , p=0.0000  , df=27
# parameter F test:         F=2.4038  , p=0.0001  , df_denom=1842, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=2.3791  , p=0.0001  , df_denom=1839, df_num=28
# ssr based chi2 test:   chi2=68.6791 , p=0.0000  , df=28
# likelihood ratio test: chi2=67.4644 , p=0.0000  , df=28
# parameter F test:         F=2.3791  , p=0.0001  , df_denom=1839, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=2.3308  , p=0.0001  , df_denom=1836, df_num=29
# ssr based chi2 test:   chi2=69.7644 , p=0.0000  , df=29
# likelihood ratio test: chi2=68.5109 , p=0.0000  , df=29
# parameter F test:         F=2.3308  , p=0.0001  , df_denom=1836, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=2.2653  , p=0.0001  , df_denom=1833, df_num=30
# ssr based chi2 test:   chi2=70.2207 , p=0.0000  , df=30
# likelihood ratio test: chi2=68.9503 , p=0.0001  , df=30
# parameter F test:         F=2.2653  , p=0.0001  , df_denom=1833, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=2.3787  , p=0.0000  , df_denom=1830, df_num=31
# ssr based chi2 test:   chi2=76.2773 , p=0.0000  , df=31
# likelihood ratio test: chi2=74.7806 , p=0.0000  , df=31
# parameter F test:         F=2.3787  , p=0.0000  , df_denom=1830, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=2.3020  , p=0.0001  , df_denom=1827, df_num=32
# ssr based chi2 test:   chi2=76.2855 , p=0.0000  , df=32
# likelihood ratio test: chi2=74.7877 , p=0.0000  , df=32
# parameter F test:         F=2.3020  , p=0.0001  , df_denom=1827, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=2.2550  , p=0.0001  , df_denom=1824, df_num=33
# ssr based chi2 test:   chi2=77.1486 , p=0.0000  , df=33
# likelihood ratio test: chi2=75.6164 , p=0.0000  , df=33
# parameter F test:         F=2.2550  , p=0.0001  , df_denom=1824, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=2.2884  , p=0.0000  , df_denom=1821, df_num=34
# ssr based chi2 test:   chi2=80.7539 , p=0.0000  , df=34
# likelihood ratio test: chi2=79.0763 , p=0.0000  , df=34
# parameter F test:         F=2.2884  , p=0.0000  , df_denom=1821, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=2.1927  , p=0.0001  , df_denom=1818, df_num=35
# ssr based chi2 test:   chi2=79.7409 , p=0.0000  , df=35
# likelihood ratio test: chi2=78.1038 , p=0.0000  , df=35
# parameter F test:         F=2.1927  , p=0.0001  , df_denom=1818, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=2.1648  , p=0.0001  , df_denom=1815, df_num=36
# ssr based chi2 test:   chi2=81.0664 , p=0.0000  , df=36
# likelihood ratio test: chi2=79.3743 , p=0.0000  , df=36
# parameter F test:         F=2.1648  , p=0.0001  , df_denom=1815, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=2.2734  , p=0.0000  , df_denom=1812, df_num=37
# ssr based chi2 test:   chi2=87.5966 , p=0.0000  , df=37
# likelihood ratio test: chi2=85.6243 , p=0.0000  , df=37
# parameter F test:         F=2.2734  , p=0.0000  , df_denom=1812, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=2.4429  , p=0.0000  , df_denom=1809, df_num=38
# ssr based chi2 test:   chi2=96.7815 , p=0.0000  , df=38
# likelihood ratio test: chi2=94.3801 , p=0.0000  , df=38
# parameter F test:         F=2.4429  , p=0.0000  , df_denom=1809, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=2.4367  , p=0.0000  , df_denom=1806, df_num=39
# ssr based chi2 test:   chi2=99.1870 , p=0.0000  , df=39
# likelihood ratio test: chi2=96.6655 , p=0.0000  , df=39
# parameter F test:         F=2.4367  , p=0.0000  , df_denom=1806, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=2.4192  , p=0.0000  , df_denom=1803, df_num=40
# ssr based chi2 test:   chi2=101.1139, p=0.0000  , df=40
# likelihood ratio test: chi2=98.4938 , p=0.0000  , df=40
# parameter F test:         F=2.4192  , p=0.0000  , df_denom=1803, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=2.3728  , p=0.0000  , df_denom=1800, df_num=41
# ssr based chi2 test:   chi2=101.7727, p=0.0000  , df=41
# likelihood ratio test: chi2=99.1176 , p=0.0000  , df=41
# parameter F test:         F=2.3728  , p=0.0000  , df_denom=1800, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=2.4008  , p=0.0000  , df_denom=1797, df_num=42
# ssr based chi2 test:   chi2=105.6013, p=0.0000  , df=42
# likelihood ratio test: chi2=102.7450, p=0.0000  , df=42
# parameter F test:         F=2.4008  , p=0.0000  , df_denom=1797, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=2.4182  , p=0.0000  , df_denom=1794, df_num=43
# ssr based chi2 test:   chi2=109.0250, p=0.0000  , df=43
# likelihood ratio test: chi2=105.9824, p=0.0000  , df=43
# parameter F test:         F=2.4182  , p=0.0000  , df_denom=1794, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=2.3721  , p=0.0000  , df_denom=1791, df_num=44
# ssr based chi2 test:   chi2=109.5575, p=0.0000  , df=44
# likelihood ratio test: chi2=106.4841, p=0.0000  , df=44
# parameter F test:         F=2.3721  , p=0.0000  , df_denom=1791, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=2.3489  , p=0.0000  , df_denom=1788, df_num=45
# ssr based chi2 test:   chi2=111.0810, p=0.0000  , df=45
# likelihood ratio test: chi2=107.9215, p=0.0000  , df=45
# parameter F test:         F=2.3489  , p=0.0000  , df_denom=1788, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=2.3203  , p=0.0000  , df_denom=1785, df_num=46
# ssr based chi2 test:   chi2=112.2941, p=0.0000  , df=46
# likelihood ratio test: chi2=109.0650, p=0.0000  , df=46
# parameter F test:         F=2.3203  , p=0.0000  , df_denom=1785, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=2.2701  , p=0.0000  , df_denom=1782, df_num=47
# ssr based chi2 test:   chi2=112.3814, p=0.0000  , df=47
# likelihood ratio test: chi2=109.1456, p=0.0000  , df=47
# parameter F test:         F=2.2701  , p=0.0000  , df_denom=1782, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=2.3318  , p=0.0000  , df_denom=1779, df_num=48
# ssr based chi2 test:   chi2=118.0278, p=0.0000  , df=48
# likelihood ratio test: chi2=114.4637, p=0.0000  , df=48
# parameter F test:         F=2.3318  , p=0.0000  , df_denom=1779, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=2.4542  , p=0.0000  , df_denom=1776, df_num=49
# ssr based chi2 test:   chi2=126.9589, p=0.0000  , df=49
# likelihood ratio test: chi2=122.8453, p=0.0000  , df=49
# parameter F test:         F=2.4542  , p=0.0000  , df_denom=1776, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=2.4072  , p=0.0000  , df_denom=1773, df_num=50
# ssr based chi2 test:   chi2=127.2168, p=0.0000  , df=50
# likelihood ratio test: chi2=123.0848, p=0.0000  , df=50
# parameter F test:         F=2.4072  , p=0.0000  , df_denom=1773, df_num=50

# %%
# Result 4- Perform Granger Causality Test with the null hypothesis of BTC doesn't Granger cause ETH

diff_ETH_BTC = pd.DataFrame()
diff_ETH_BTC['ETH'] = diff_ETH
diff_ETH_BTC['BTC'] = diff_BTC
print('Result 4')
cor = sm.grangercausalitytests(diff_ETH_BTC, 50)
# Out:
# Result 4
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2211  , p=0.6382  , df_denom=1920, df_num=1
# ssr based chi2 test:   chi2=0.2215  , p=0.6379  , df=1
# likelihood ratio test: chi2=0.2215  , p=0.6379  , df=1
# parameter F test:         F=0.2211  , p=0.6382  , df_denom=1920, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.1561  , p=0.0158  , df_denom=1917, df_num=2
# ssr based chi2 test:   chi2=8.3338  , p=0.0155  , df=2
# likelihood ratio test: chi2=8.3158  , p=0.0156  , df=2
# parameter F test:         F=4.1561  , p=0.0158  , df_denom=1917, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.2234  , p=0.0001  , df_denom=1914, df_num=3
# ssr based chi2 test:   chi2=21.7495 , p=0.0001  , df=3
# likelihood ratio test: chi2=21.6273 , p=0.0001  , df=3
# parameter F test:         F=7.2234  , p=0.0001  , df_denom=1914, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.7567  , p=0.0008  , df_denom=1911, df_num=4
# ssr based chi2 test:   chi2=19.1166 , p=0.0007  , df=4
# likelihood ratio test: chi2=19.0221 , p=0.0008  , df=4
# parameter F test:         F=4.7567  , p=0.0008  , df_denom=1911, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.1755  , p=0.0074  , df_denom=1908, df_num=5
# ssr based chi2 test:   chi2=15.9692 , p=0.0069  , df=5
# likelihood ratio test: chi2=15.9031 , p=0.0071  , df=5
# parameter F test:         F=3.1755  , p=0.0074  , df_denom=1908, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.4969  , p=0.0002  , df_denom=1905, df_num=6
# ssr based chi2 test:   chi2=27.1652 , p=0.0001  , df=6
# likelihood ratio test: chi2=26.9747 , p=0.0001  , df=6
# parameter F test:         F=4.4969  , p=0.0002  , df_denom=1905, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.0197  , p=0.0037  , df_denom=1902, df_num=7
# ssr based chi2 test:   chi2=21.3049 , p=0.0033  , df=7
# likelihood ratio test: chi2=21.1874 , p=0.0035  , df=7
# parameter F test:         F=3.0197  , p=0.0037  , df_denom=1902, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.9565  , p=0.0027  , df_denom=1899, df_num=8
# ssr based chi2 test:   chi2=23.8641 , p=0.0024  , df=8
# likelihood ratio test: chi2=23.7167 , p=0.0026  , df=8
# parameter F test:         F=2.9565  , p=0.0027  , df_denom=1899, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.8044  , p=0.0028  , df_denom=1896, df_num=9
# ssr based chi2 test:   chi2=25.4925 , p=0.0025  , df=9
# likelihood ratio test: chi2=25.3243 , p=0.0026  , df=9
# parameter F test:         F=2.8044  , p=0.0028  , df_denom=1896, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.9903  , p=0.0009  , df_denom=1893, df_num=10
# ssr based chi2 test:   chi2=30.2352 , p=0.0008  , df=10
# likelihood ratio test: chi2=29.9989 , p=0.0009  , df=10
# parameter F test:         F=2.9903  , p=0.0009  , df_denom=1893, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=2.6236  , p=0.0025  , df_denom=1890, df_num=11
# ssr based chi2 test:   chi2=29.2112 , p=0.0021  , df=11
# likelihood ratio test: chi2=28.9905 , p=0.0023  , df=11
# parameter F test:         F=2.6236  , p=0.0025  , df_denom=1890, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=2.6540  , p=0.0016  , df_denom=1887, df_num=12
# ssr based chi2 test:   chi2=32.2703 , p=0.0013  , df=12
# likelihood ratio test: chi2=32.0010 , p=0.0014  , df=12
# parameter F test:         F=2.6540  , p=0.0016  , df_denom=1887, df_num=12
#
# Granger Causality
# number of lags (no zero) 13
# ssr based F test:         F=2.6927  , p=0.0009  , df_denom=1884, df_num=13
# ssr based chi2 test:   chi2=35.5066 , p=0.0007  , df=13
# likelihood ratio test: chi2=35.1807 , p=0.0008  , df=13
# parameter F test:         F=2.6927  , p=0.0009  , df_denom=1884, df_num=13
#
# Granger Causality
# number of lags (no zero) 14
# ssr based F test:         F=2.1947  , p=0.0064  , df_denom=1881, df_num=14
# ssr based chi2 test:   chi2=31.1995 , p=0.0052  , df=14
# likelihood ratio test: chi2=30.9474 , p=0.0056  , df=14
# parameter F test:         F=2.1947  , p=0.0064  , df_denom=1881, df_num=14
#
# Granger Causality
# number of lags (no zero) 15
# ssr based F test:         F=2.2094  , p=0.0047  , df_denom=1878, df_num=15
# ssr based chi2 test:   chi2=33.6877 , p=0.0038  , df=15
# likelihood ratio test: chi2=33.3939 , p=0.0041  , df=15
# parameter F test:         F=2.2094  , p=0.0047  , df_denom=1878, df_num=15
#
# Granger Causality
# number of lags (no zero) 16
# ssr based F test:         F=2.1560  , p=0.0049  , df_denom=1875, df_num=16
# ssr based chi2 test:   chi2=35.1036 , p=0.0038  , df=16
# likelihood ratio test: chi2=34.7845 , p=0.0043  , df=16
# parameter F test:         F=2.1560  , p=0.0049  , df_denom=1875, df_num=16
#
# Granger Causality
# number of lags (no zero) 17
# ssr based F test:         F=2.3409  , p=0.0015  , df_denom=1872, df_num=17
# ssr based chi2 test:   chi2=40.5390 , p=0.0011  , df=17
# likelihood ratio test: chi2=40.1141 , p=0.0012  , df=17
# parameter F test:         F=2.3409  , p=0.0015  , df_denom=1872, df_num=17
#
# Granger Causality
# number of lags (no zero) 18
# ssr based F test:         F=2.6532  , p=0.0002  , df_denom=1869, df_num=18
# ssr based chi2 test:   chi2=48.7030 , p=0.0001  , df=18
# likelihood ratio test: chi2=48.0911 , p=0.0001  , df=18
# parameter F test:         F=2.6532  , p=0.0002  , df_denom=1869, df_num=18
#
# Granger Causality
# number of lags (no zero) 19
# ssr based F test:         F=2.4480  , p=0.0005  , df_denom=1866, df_num=19
# ssr based chi2 test:   chi2=47.4839 , p=0.0003  , df=19
# likelihood ratio test: chi2=46.9018 , p=0.0004  , df=19
# parameter F test:         F=2.4480  , p=0.0005  , df_denom=1866, df_num=19
#
# Granger Causality
# number of lags (no zero) 20
# ssr based F test:         F=2.5195  , p=0.0002  , df_denom=1863, df_num=20
# ssr based chi2 test:   chi2=51.4985 , p=0.0001  , df=20
# likelihood ratio test: chi2=50.8143 , p=0.0002  , df=20
# parameter F test:         F=2.5195  , p=0.0002  , df_denom=1863, df_num=20
#
# Granger Causality
# number of lags (no zero) 21
# ssr based F test:         F=2.3645  , p=0.0005  , df_denom=1860, df_num=21
# ssr based chi2 test:   chi2=50.8029 , p=0.0003  , df=21
# likelihood ratio test: chi2=50.1367 , p=0.0003  , df=21
# parameter F test:         F=2.3645  , p=0.0005  , df_denom=1860, df_num=21
#
# Granger Causality
# number of lags (no zero) 22
# ssr based F test:         F=2.4058  , p=0.0003  , df_denom=1857, df_num=22
# ssr based chi2 test:   chi2=54.2104 , p=0.0002  , df=22
# likelihood ratio test: chi2=53.4522 , p=0.0002  , df=22
# parameter F test:         F=2.4058  , p=0.0003  , df_denom=1857, df_num=22
#
# Granger Causality
# number of lags (no zero) 23
# ssr based F test:         F=2.5426  , p=0.0001  , df_denom=1854, df_num=23
# ssr based chi2 test:   chi2=59.9612 , p=0.0000  , df=23
# likelihood ratio test: chi2=59.0350 , p=0.0001  , df=23
# parameter F test:         F=2.5426  , p=0.0001  , df_denom=1854, df_num=23
#
# Granger Causality
# number of lags (no zero) 24
# ssr based F test:         F=2.5542  , p=0.0001  , df_denom=1851, df_num=24
# ssr based chi2 test:   chi2=62.9234 , p=0.0000  , df=24
# likelihood ratio test: chi2=61.9039 , p=0.0000  , df=24
# parameter F test:         F=2.5542  , p=0.0001  , df_denom=1851, df_num=24
#
# Granger Causality
# number of lags (no zero) 25
# ssr based F test:         F=2.7894  , p=0.0000  , df_denom=1848, df_num=25
# ssr based chi2 test:   chi2=71.6600 , p=0.0000  , df=25
# likelihood ratio test: chi2=70.3411 , p=0.0000  , df=25
# parameter F test:         F=2.7894  , p=0.0000  , df_denom=1848, df_num=25
#
# Granger Causality
# number of lags (no zero) 26
# ssr based F test:         F=2.6662  , p=0.0000  , df_denom=1845, df_num=26
# ssr based chi2 test:   chi2=71.3116 , p=0.0000  , df=26
# likelihood ratio test: chi2=70.0046 , p=0.0000  , df=26
# parameter F test:         F=2.6662  , p=0.0000  , df_denom=1845, df_num=26
#
# Granger Causality
# number of lags (no zero) 27
# ssr based F test:         F=2.5500  , p=0.0000  , df_denom=1842, df_num=27
# ssr based chi2 test:   chi2=70.9064 , p=0.0000  , df=27
# likelihood ratio test: chi2=69.6133 , p=0.0000  , df=27
# parameter F test:         F=2.5500  , p=0.0000  , df_denom=1842, df_num=27
#
# Granger Causality
# number of lags (no zero) 28
# ssr based F test:         F=2.4631  , p=0.0000  , df_denom=1839, df_num=28
# ssr based chi2 test:   chi2=71.1051 , p=0.0000  , df=28
# likelihood ratio test: chi2=69.8042 , p=0.0000  , df=28
# parameter F test:         F=2.4631  , p=0.0000  , df_denom=1839, df_num=28
#
# Granger Causality
# number of lags (no zero) 29
# ssr based F test:         F=2.4702  , p=0.0000  , df_denom=1836, df_num=29
# ssr based chi2 test:   chi2=73.9388 , p=0.0000  , df=29
# likelihood ratio test: chi2=72.5328 , p=0.0000  , df=29
# parameter F test:         F=2.4702  , p=0.0000  , df_denom=1836, df_num=29
#
# Granger Causality
# number of lags (no zero) 30
# ssr based F test:         F=2.3741  , p=0.0000  , df_denom=1833, df_num=30
# ssr based chi2 test:   chi2=73.5924 , p=0.0000  , df=30
# likelihood ratio test: chi2=72.1986 , p=0.0000  , df=30
# parameter F test:         F=2.3741  , p=0.0000  , df_denom=1833, df_num=30
#
# Granger Causality
# number of lags (no zero) 31
# ssr based F test:         F=2.3401  , p=0.0000  , df_denom=1830, df_num=31
# ssr based chi2 test:   chi2=75.0394 , p=0.0000  , df=31
# likelihood ratio test: chi2=73.5903 , p=0.0000  , df=31
# parameter F test:         F=2.3401  , p=0.0000  , df_denom=1830, df_num=31
#
# Granger Causality
# number of lags (no zero) 32
# ssr based F test:         F=2.2426  , p=0.0001  , df_denom=1827, df_num=32
# ssr based chi2 test:   chi2=74.3170 , p=0.0000  , df=32
# likelihood ratio test: chi2=72.8945 , p=0.0000  , df=32
# parameter F test:         F=2.2426  , p=0.0001  , df_denom=1827, df_num=32
#
# Granger Causality
# number of lags (no zero) 33
# ssr based F test:         F=2.1149  , p=0.0002  , df_denom=1824, df_num=33
# ssr based chi2 test:   chi2=72.3554 , p=0.0001  , df=33
# likelihood ratio test: chi2=71.0055 , p=0.0001  , df=33
# parameter F test:         F=2.1149  , p=0.0002  , df_denom=1824, df_num=33
#
# Granger Causality
# number of lags (no zero) 34
# ssr based F test:         F=2.0962  , p=0.0002  , df_denom=1821, df_num=34
# ssr based chi2 test:   chi2=73.9726 , p=0.0001  , df=34
# likelihood ratio test: chi2=72.5617 , p=0.0001  , df=34
# parameter F test:         F=2.0962  , p=0.0002  , df_denom=1821, df_num=34
#
# Granger Causality
# number of lags (no zero) 35
# ssr based F test:         F=2.0894  , p=0.0002  , df_denom=1818, df_num=35
# ssr based chi2 test:   chi2=75.9833 , p=0.0001  , df=35
# likelihood ratio test: chi2=74.4949 , p=0.0001  , df=35
# parameter F test:         F=2.0894  , p=0.0002  , df_denom=1818, df_num=35
#
# Granger Causality
# number of lags (no zero) 36
# ssr based F test:         F=2.0111  , p=0.0004  , df_denom=1815, df_num=36
# ssr based chi2 test:   chi2=75.3104 , p=0.0001  , df=36
# likelihood ratio test: chi2=73.8472 , p=0.0002  , df=36
# parameter F test:         F=2.0111  , p=0.0004  , df_denom=1815, df_num=36
#
# Granger Causality
# number of lags (no zero) 37
# ssr based F test:         F=2.0327  , p=0.0003  , df_denom=1812, df_num=37
# ssr based chi2 test:   chi2=78.3240 , p=0.0001  , df=37
# likelihood ratio test: chi2=76.7421 , p=0.0001  , df=37
# parameter F test:         F=2.0327  , p=0.0003  , df_denom=1812, df_num=37
#
# Granger Causality
# number of lags (no zero) 38
# ssr based F test:         F=2.5138  , p=0.0000  , df_denom=1809, df_num=38
# ssr based chi2 test:   chi2=99.5903 , p=0.0000  , df=38
# likelihood ratio test: chi2=97.0499 , p=0.0000  , df=38
# parameter F test:         F=2.5138  , p=0.0000  , df_denom=1809, df_num=38
#
# Granger Causality
# number of lags (no zero) 39
# ssr based F test:         F=2.5233  , p=0.0000  , df_denom=1806, df_num=39
# ssr based chi2 test:   chi2=102.7127, p=0.0000  , df=39
# likelihood ratio test: chi2=100.0120, p=0.0000  , df=39
# parameter F test:         F=2.5233  , p=0.0000  , df_denom=1806, df_num=39
#
# Granger Causality
# number of lags (no zero) 40
# ssr based F test:         F=2.5259  , p=0.0000  , df_denom=1803, df_num=40
# ssr based chi2 test:   chi2=105.5742, p=0.0000  , df=40
# likelihood ratio test: chi2=102.7222, p=0.0000  , df=40
# parameter F test:         F=2.5259  , p=0.0000  , df_denom=1803, df_num=40
#
# Granger Causality
# number of lags (no zero) 41
# ssr based F test:         F=2.4146  , p=0.0000  , df_denom=1800, df_num=41
# ssr based chi2 test:   chi2=103.5628, p=0.0000  , df=41
# likelihood ratio test: chi2=100.8152, p=0.0000  , df=41
# parameter F test:         F=2.4146  , p=0.0000  , df_denom=1800, df_num=41
#
# Granger Causality
# number of lags (no zero) 42
# ssr based F test:         F=2.3661  , p=0.0000  , df_denom=1797, df_num=42
# ssr based chi2 test:   chi2=104.0769, p=0.0000  , df=42
# likelihood ratio test: chi2=101.3010, p=0.0000  , df=42
# parameter F test:         F=2.3661  , p=0.0000  , df_denom=1797, df_num=42
#
# Granger Causality
# number of lags (no zero) 43
# ssr based F test:         F=2.3397  , p=0.0000  , df_denom=1794, df_num=43
# ssr based chi2 test:   chi2=105.4881, p=0.0000  , df=43
# likelihood ratio test: chi2=102.6363, p=0.0000  , df=43
# parameter F test:         F=2.3397  , p=0.0000  , df_denom=1794, df_num=43
#
# Granger Causality
# number of lags (no zero) 44
# ssr based F test:         F=2.4870  , p=0.0000  , df_denom=1791, df_num=44
# ssr based chi2 test:   chi2=114.8651, p=0.0000  , df=44
# likelihood ratio test: chi2=111.4928, p=0.0000  , df=44
# parameter F test:         F=2.4870  , p=0.0000  , df_denom=1791, df_num=44
#
# Granger Causality
# number of lags (no zero) 45
# ssr based F test:         F=2.4709  , p=0.0000  , df_denom=1788, df_num=45
# ssr based chi2 test:   chi2=116.8502, p=0.0000  , df=45
# likelihood ratio test: chi2=113.3609, p=0.0000  , df=45
# parameter F test:         F=2.4709  , p=0.0000  , df_denom=1788, df_num=45
#
# Granger Causality
# number of lags (no zero) 46
# ssr based F test:         F=2.5159  , p=0.0000  , df_denom=1785, df_num=46
# ssr based chi2 test:   chi2=121.7626, p=0.0000  , df=46
# likelihood ratio test: chi2=117.9780, p=0.0000  , df=46
# parameter F test:         F=2.5159  , p=0.0000  , df_denom=1785, df_num=46
#
# Granger Causality
# number of lags (no zero) 47
# ssr based F test:         F=2.4657  , p=0.0000  , df_denom=1782, df_num=47
# ssr based chi2 test:   chi2=122.0660, p=0.0000  , df=47
# likelihood ratio test: chi2=118.2610, p=0.0000  , df=47
# parameter F test:         F=2.4657  , p=0.0000  , df_denom=1782, df_num=47
#
# Granger Causality
# number of lags (no zero) 48
# ssr based F test:         F=2.5698  , p=0.0000  , df_denom=1779, df_num=48
# ssr based chi2 test:   chi2=130.0756, p=0.0000  , df=48
# likelihood ratio test: chi2=125.7642, p=0.0000  , df=48
# parameter F test:         F=2.5698  , p=0.0000  , df_denom=1779, df_num=48
#
# Granger Causality
# number of lags (no zero) 49
# ssr based F test:         F=2.5879  , p=0.0000  , df_denom=1776, df_num=49
# ssr based chi2 test:   chi2=133.8777, p=0.0000  , df=49
# likelihood ratio test: chi2=129.3141, p=0.0000  , df=49
# parameter F test:         F=2.5879  , p=0.0000  , df_denom=1776, df_num=49
#
# Granger Causality
# number of lags (no zero) 50
# ssr based F test:         F=2.5953  , p=0.0000  , df_denom=1773, df_num=50
# ssr based chi2 test:   chi2=137.1580, p=0.0000  , df=50
# likelihood ratio test: chi2=132.3709, p=0.0000  , df=50
# parameter F test:         F=2.5953  , p=0.0000  , df_denom=1773, df_num=50

# %% [markdown]
# Based on **Result 3-4**, it's most likely that BTC causes ETH. From ~lag 4 to ~lag 16 (4-16 hours), we observed >99% confidence level. On the other hand, Granger Test failed to prove that ETH causes BTC(failed to reject the null hypothesis). However, the p values improve beyond ~lag 50 (~2days), with confidence level of ~90%.

# %%
# Plot 9- ACF plot of the differenced series using lag 1 order 1

from statsmodels.graphics.tsaplots import plot_acf
from pandas import tseries
plot_acf(diff_ETH)
plt.title('Plot 9- ETH', loc='center')
plt.xlim((0, 100))
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plot_acf(diff_BTC)
plt.title('Plot 9- BTC', loc='center')
plt.xlim((0, 100))
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.show()

# %%
# Plot 10- PACF plot of the differenced series using lag 1 order 1

from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf

plot_pacf(diff_ETH, lags=80)
plt.title('Plot 10- ETH', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')

plot_pacf(diff_BTC, lags=80)
plt.title('Plot 10- BTC', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')
plt.show()

# %% [markdown]
# Since there combinations of lag difference and difference order we could pick from, the following sections explore the combinations.

# %%
# Dickey Fuller Test result, ACF, and PACF plots of differenced series using lag 2 order 1

DF_diff_2 = adfuller(diff_2)
print('\n')
print('ADF Statistic: %f' % DF_diff_2[0])
print('p-value: %f' % DF_diff_2[1])
print('Critical Values:')
for key, value in DF_diff_2[4].items():
    print('\t%s: %.3f' % (key, value))
    
plot_acf(diff_2)
plt.title('Plot 11- diff_2 ACF', loc='center')
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.xlim([0, 80])
plt.show()

plot_pacf(diff_2, lags=80)
plt.title('Plot 12- diff_2 PACF', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')    
plt.show()
# Out:
# ADF Statistic: -7.999024
# p-value: 0.000000
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %%
# Dickey Fuller Test result, ACF, and PACF plots of differenced series using lag 2 order 1

DF_diff_24 = adfuller(diff_24)
print('\n')
print('ADF Statistic: %f' % DF_diff_24[0])
print('p-value: %f' % DF_diff_24[1])
print('Critical Values:')
for key, value in DF_diff_24[4].items():
    print('\t%s: %.3f' % (key, value))
    
plot_acf(diff_24)
plt.title('Plot 13- diff_24 ACF', loc='center')
plt.ylabel('ACF')
plt.xlabel('Lag(s)')
plt.xlim([0, 80])
plt.show()

plot_pacf(diff_24, lags=80)
plt.title('Plot 14- diff_2 PACF', loc='center')
plt.ylabel('PACF')
plt.xlabel('Lag(s)')    
plt.show()
# Out:
# ADF Statistic: -4.483549
# p-value: 0.000211
# Critical Values:
# 	1%: -3.435
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# ### Conclusion:
# -  There seem to be high correlation between the rise in search frequency and the drop in currencies prices
# -  High correlation between BTC and ETH ( >99% confidence level )
# -  There is a low correlation between an observation and it's lag 1 (x_t and x_t-1)
# -  Both series have no obvious trends or seasonalities
# -  Spike is more "rapid" than fall
# -  BTC and ETH prices (scaled) converged during fall, but not spike
# <br><br>
# From the conclusion above, my hypothesis is that classical time series analysis ( historical prices alone) might be insufficent when predicting such volatile markets. Using Machine Learning with variety of predictorss such GoogleNews search frequency and relationship with other correlated coins on top of ARIMA model will improve prediction performance significantly.

# %% [markdown]
# ### Next steps:
# 1. Search for more potential features: social media APIs? macroeconomic covariates? differencing function? node count? mining time? GPU sales (AMD, Nvidia)?
# 2. Identify cointegrated crytocurrency pairs (based on Granger Test) and model the relationship between the pairs
# 3. Analyze price history using ARIMA model
# 4. Based on 1,2,3 come up with a Machine Learning model that best predict future prices
# 5. Compare the Machine Learning model performance with ARIMA performance

# %%
#ar1
